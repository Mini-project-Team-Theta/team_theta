# %%
import pandas as pd
import os
from glob import glob

# %%
CURR_DIR_PATH = "C:/Brights_Projects/MiniProject2"

data_dir = CURR_DIR_PATH + "/data/"
target_dir = CURR_DIR_PATH + "/target/"

# %%
def create_concat_file(file_paths, snow_depth, column_names):
    df_list = []
 
    for file_path in file_paths:
        file_df = pd.read_csv(file_path)
        df_list.append(file_df)
 
    concatenated_df = pd.concat(df_list)
    concatenated_df.columns = column_names
    concatenated_df.to_csv(target_dir + f"zip/{snow_depth}_kuopiosnowdepth.csv", index=False)

# %%
snow_file_path = glob(data_dir + "Tahko_snow_*")

# %%
snow_file_path
# Out:
# ['C:/Brights_Projects/MiniProject2/data\\Tahko_snow_1.1.2004_31.12.2013_kuopiosnowdepth.csv',
#  'C:/Brights_Projects/MiniProject2/data\\Tahko_snow_1.1.2014_1.12.2024_kuopiosnowdepth.csv']

# %%
snow_columns = ["Observation station", "Year", "Month", "Day","Time [Local time]", "Snow depth [cm]"]

# %%
create_concat_file(snow_file_path, "kuopio", snow_columns)

# %%
def create_concat_file(file_paths, airtemp, column_names):
    df_list = []
 
    for file_path in file_paths:
        file_df = pd.read_csv(file_path)
        df_list.append(file_df)
 
    concatenated_df = pd.concat(df_list)
    concatenated_df.columns = column_names
    concatenated_df.to_csv(target_dir + f"zip/{airtemp}_kuopioairtemp.csv", index=False)

# %%
air_file_path = glob(data_dir + "Tahko_air_*")

# %%
air_file_path
# Out:
# ['C:/Brights_Projects/MiniProject2/data\\Tahko_air_1.1.2004_1.12.2013_kuopioairtemp.csv',
#  'C:/Brights_Projects/MiniProject2/data\\Tahko_air_1.1.2014 - 1.12.2024_kuopioairtemp.csv']

# %%
air_columns = ["Observation station", "Year", "Month", "Day","Time [Local time]", "Average temperature [°C]"]

# %%
create_concat_file(air_file_path, "kuopio", air_columns)

# %%
kuopio_snow = pd.read_csv("C:/Brights_Projects/MiniProject2/target/zip/kuopio_kuopiosnowdepth.csv")
kuopio_air = pd.read_csv("C:/Brights_Projects/MiniProject2/target/zip/kuopio_kuopioairtemp.csv")
kuopio_air
# Out:
#      Observation station  Year  Month  Day Time [Local time]  \
# 0        Kuopio Maaninka  2004      1    1              2:00
# 1        Kuopio Maaninka  2004      1    2              2:00
# 2        Kuopio Maaninka  2004      1    3              2:00
# 3        Kuopio Maaninka  2004      1    4              2:00
# 4        Kuopio Maaninka  2004      1    5              2:00
# ...                  ...   ...    ...  ...               ...
# 7586     Kuopio Maaninka  2024     11   27              2:00
# 7587     Kuopio Maaninka  2024     11   28              2:00
# 7588     Kuopio Maaninka  2024     11   29              2:00
# 7589     Kuopio Maaninka  2024     11   30              2:00
# 7590     Kuopio Maaninka  2024     12    1              2:00
#
#      Average temperature [°C]
# 0                       -21.0
# 1                       -21.2
# 2                       -14.8
# 3                       -11.8
# 4                       -10.3
# ...                       ...
# 7586                        4
# 7587                      3.2
# 7588                      0.6
# 7589                     -0.8
# 7590                      4.3
#
# [7591 rows x 6 columns]

# %%
date_range = pd.date_range(start="2004-01-01", end="2024-12-31", freq="D")
kuopio_snow["Date_range"] = date_range
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[575], line 2
#       1 date_range = pd.date_range(start="2004-01-01", end="2024-12-31", freq="D")
# ----> 2 kuopio_snow["Date_range"] = date_range
#
# File c:\Users\JonnaWaddington\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File c:\Users\JonnaWaddington\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\JonnaWaddington\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File c:\Users\JonnaWaddington\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (7671) does not match length of index (7624)

# %%
date_range = pd.date_range(start="2004-01-01", end="2024-12-31", freq="D")

df = pd.DataFrame(date_range, columns=["Date"])

# %%
kuopio_air["Date"] = pd.to_datetime(kuopio_air[["Year", "Month", "Day"]])
kuopio_air
# Out:
#      Observation station  Year  Month  Day Time [Local time]  \
# 0        Kuopio Maaninka  2004      1    1              2:00
# 1        Kuopio Maaninka  2004      1    2              2:00
# 2        Kuopio Maaninka  2004      1    3              2:00
# 3        Kuopio Maaninka  2004      1    4              2:00
# 4        Kuopio Maaninka  2004      1    5              2:00
# ...                  ...   ...    ...  ...               ...
# 7586     Kuopio Maaninka  2024     11   27              2:00
# 7587     Kuopio Maaninka  2024     11   28              2:00
# 7588     Kuopio Maaninka  2024     11   29              2:00
# 7589     Kuopio Maaninka  2024     11   30              2:00
# 7590     Kuopio Maaninka  2024     12    1              2:00
#
#      Average temperature [°C]       Date
# 0                       -21.0 2004-01-01
# 1                       -21.2 2004-01-02
# 2                       -14.8 2004-01-03
# 3                       -11.8 2004-01-04
# 4                       -10.3 2004-01-05
# ...                       ...        ...
# 7586                        4 2024-11-27
# 7587                      3.2 2024-11-28
# 7588                      0.6 2024-11-29
# 7589                     -0.8 2024-11-30
# 7590                      4.3 2024-12-01
#
# [7591 rows x 7 columns]

# %%
kuopio_air = kuopio_air.drop(["Observation station", "Year", "Month", "Day","Time [Local time]"], axis=1)

# %%
merged_columns = kuopio_snow.merge(kuopio_air, on="Date")
merged_columns
# Out:
#      Observation station  Year  Month  Day Time [Local time] Snow depth [cm]  \
# 0        Kuopio Maaninka  2004      1    1              2:00              21
# 1        Kuopio Maaninka  2004      1    2              2:00              21
# 2        Kuopio Maaninka  2004      1    3              2:00              21
# 3        Kuopio Maaninka  2004      1    4              2:00              21
# 4        Kuopio Maaninka  2004      1    5              2:00              23
# ...                  ...   ...    ...  ...               ...             ...
# 7569     Kuopio Maaninka  2024     11   27              2:00              -1
# 7570     Kuopio Maaninka  2024     11   28              2:00              -1
# 7571     Kuopio Maaninka  2024     11   29              2:00              -1
# 7572     Kuopio Maaninka  2024     11   30              2:00              -1
# 7573     Kuopio Maaninka  2024     12    1              2:00               2
#
#            Date Average temperature [°C]
# 0    2004-01-01                    -21.0
# 1    2004-01-02                    -21.2
# 2    2004-01-03                    -14.8
# 3    2004-01-04                    -11.8
# 4    2004-01-05                    -10.3
# ...         ...                      ...
# 7569 2024-11-27                        4
# 7570 2024-11-28                      3.2
# 7571 2024-11-29                      0.6
# 7572 2024-11-30                     -0.8
# 7573 2024-12-01                      4.3
#
# [7574 rows x 8 columns]

# %%
def create_concat_file(file_paths, cloud, column_names):
    df_list = []
 
    for file_path in file_paths:
        file_df = pd.read_csv(file_path)
        df_list.append(file_df)
 
    concatenated_df = pd.concat(df_list)
    concatenated_df.columns = column_names
    concatenated_df.to_csv(target_dir + f"zip/{cloud}_kuopiocloud.csv", index=False)

# %%
cloud_file_path = glob(data_dir + "Tahko_cloud_*")

# %%
cloud_columns = ["Observation station", "Year", "Month", "Day","Time [Local time]", "Cloud cover [1/8]"]

# %%
create_concat_file(cloud_file_path, "kuopio", cloud_columns)

# %%
kuopio_cloud = pd.read_csv("C:/Brights_Projects/MiniProject2/target/zip/kuopio_kuopiocloud.csv")
kuopio_cloud
# Out:
#                Observation station  Year  Month  Day Time [Local time]  \
# 0       Siilinjärvi Kuopio airport  2015      1    1              0:00
# 1       Siilinjärvi Kuopio airport  2015      1    2              0:00
# 2       Siilinjärvi Kuopio airport  2015      1    3              0:00
# 3       Siilinjärvi Kuopio airport  2015      1    4              0:00
# 4       Siilinjärvi Kuopio airport  2015      1    5              0:00
# ...                            ...   ...    ...  ...               ...
# 156389  Siilinjärvi Kuopio airport  2024     12   27              0:00
# 156390  Siilinjärvi Kuopio airport  2024     12   28              0:00
# 156391  Siilinjärvi Kuopio airport  2024     12   29              0:00
# 156392  Siilinjärvi Kuopio airport  2024     12   30              0:00
# 156393  Siilinjärvi Kuopio airport  2024     12   31              0:00
#
#           Cloud cover [1/8]
# 0              Cloudy (8/8)
# 1              Cloudy (8/8)
# 2              Cloudy (8/8)
# 3              Cloudy (8/8)
# 4       Mostly cloudy (7/8)
# ...                     ...
# 156389          Clear (0/8)
# 156390          Clear (0/8)
# 156391         Cloudy (8/8)
# 156392  Mostly cloudy (7/8)
# 156393          Clear (0/8)
#
# [156394 rows x 6 columns]

# %%
kuopio_cloud["Date"] = pd.to_datetime(kuopio_cloud[["Year", "Month", "Day"]])
kuopio_cloud
# Out:
#                Observation station  Year  Month  Day Time [Local time]  \
# 0       Siilinjärvi Kuopio airport  2015      1    1              0:00
# 1       Siilinjärvi Kuopio airport  2015      1    2              0:00
# 2       Siilinjärvi Kuopio airport  2015      1    3              0:00
# 3       Siilinjärvi Kuopio airport  2015      1    4              0:00
# 4       Siilinjärvi Kuopio airport  2015      1    5              0:00
# ...                            ...   ...    ...  ...               ...
# 156389  Siilinjärvi Kuopio airport  2024     12   27              0:00
# 156390  Siilinjärvi Kuopio airport  2024     12   28              0:00
# 156391  Siilinjärvi Kuopio airport  2024     12   29              0:00
# 156392  Siilinjärvi Kuopio airport  2024     12   30              0:00
# 156393  Siilinjärvi Kuopio airport  2024     12   31              0:00
#
#           Cloud cover [1/8]       Date
# 0              Cloudy (8/8) 2015-01-01
# 1              Cloudy (8/8) 2015-01-02
# 2              Cloudy (8/8) 2015-01-03
# 3              Cloudy (8/8) 2015-01-04
# 4       Mostly cloudy (7/8) 2015-01-05
# ...                     ...        ...
# 156389          Clear (0/8) 2024-12-27
# 156390          Clear (0/8) 2024-12-28
# 156391         Cloudy (8/8) 2024-12-29
# 156392  Mostly cloudy (7/8) 2024-12-30
# 156393          Clear (0/8) 2024-12-31
#
# [156394 rows x 7 columns]

# %%
kuopio_cloud["cloud_code"] = kuopio_cloud["Cloud cover [1/8]"].fillna("")

# %%
kuopio_cloud["cloud_code"] = (
    kuopio_cloud["cloud_code"]
    .astype(str)  # Convert to string in case of mixed types
    .str.extract(r"(\d+)/\d+")  # Extract the first number before "/"
    .astype(float)  # Convert to float
)
kuopio_cloud
# Out:
#                Observation station  Year  Month  Day Time [Local time]  \
# 0       Siilinjärvi Kuopio airport  2015      1    1              0:00
# 1       Siilinjärvi Kuopio airport  2015      1    2              0:00
# 2       Siilinjärvi Kuopio airport  2015      1    3              0:00
# 3       Siilinjärvi Kuopio airport  2015      1    4              0:00
# 4       Siilinjärvi Kuopio airport  2015      1    5              0:00
# ...                            ...   ...    ...  ...               ...
# 156389  Siilinjärvi Kuopio airport  2024     12   27              0:00
# 156390  Siilinjärvi Kuopio airport  2024     12   28              0:00
# 156391  Siilinjärvi Kuopio airport  2024     12   29              0:00
# 156392  Siilinjärvi Kuopio airport  2024     12   30              0:00
# 156393  Siilinjärvi Kuopio airport  2024     12   31              0:00
#
#           Cloud cover [1/8]       Date  cloud_code
# 0              Cloudy (8/8) 2015-01-01         8.0
# 1              Cloudy (8/8) 2015-01-02         8.0
# 2              Cloudy (8/8) 2015-01-03         8.0
# 3              Cloudy (8/8) 2015-01-04         8.0
# 4       Mostly cloudy (7/8) 2015-01-05         7.0
# ...                     ...        ...         ...
# 156389          Clear (0/8) 2024-12-27         0.0
# 156390          Clear (0/8) 2024-12-28         0.0
# 156391         Cloudy (8/8) 2024-12-29         8.0
# 156392  Mostly cloudy (7/8) 2024-12-30         7.0
# 156393          Clear (0/8) 2024-12-31         0.0
#
# [156394 rows x 8 columns]

# %%
kuopio_cloud = kuopio_cloud.groupby("Date", as_index=False).mean(numeric_only=True)
kuopio_cloud
# Out:
#            Date    Year  Month   Day  cloud_code
# 0    2004-01-01  2004.0    1.0   1.0    0.000000
# 1    2004-01-02  2004.0    1.0   2.0    5.347222
# 2    2004-01-03  2004.0    1.0   3.0    6.083333
# 3    2004-01-04  2004.0    1.0   4.0    7.069444
# 4    2004-01-05  2004.0    1.0   5.0    7.250000
# ...         ...     ...    ...   ...         ...
# 5907 2024-12-27  2024.0   12.0  27.0    0.000000
# 5908 2024-12-28  2024.0   12.0  28.0    0.000000
# 5909 2024-12-29  2024.0   12.0  29.0    8.000000
# 5910 2024-12-30  2024.0   12.0  30.0    7.000000
# 5911 2024-12-31  2024.0   12.0  31.0    0.000000
#
# [5912 rows x 5 columns]

# %%
#kuopio_cloud["cloud_code"] = merged_columns["Cloud cover [1/8]"].str.extract(r"(\d+)/\d+").astype(float)

# %%
#kuopio_cloud = kuopio_cloud.drop(["Observation station", "Year", "Month", "Day","Time [Local time]"], axis=1)

# %%
#merged_columns = kuopio_snow.merge(kuopio_air, on="Date").merge(kuopio_cloud, on="Date")
#merged_columns

# %%
#merged_columns = merged_columns.drop_duplicates()
#merged_columns.info

# %%
#merged_columns.to_csv(target_dir + "zip/tahko_kuopio_weather.csv", index=False)
